# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("../Kaggle_Housing_Prices/train.csv")
pd.options.display.max_columns=None

data.head(2)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500

# %%
clean_df=data.copy()

# %%
## drop Id.  DF has index
clean_df.drop("Id", axis=1, inplace=True)
#clean_df.head(2)

# %%
#clean_df[['MSSubClass', 'SalePrice']].groupby('MSSubClass').median().sort_values(by='SalePrice', ascending=True)

# %%
#  MSSubClass could be made linear integers based on median SalePrice in that class.  

SubClassNumber=[]

for each in clean_df["MSSubClass"]:
    if each == 20:
        cat=11
    elif each == 30:
        cat=2
    elif each == 40:
        cat=8
    elif each == 45:
        cat=3
    elif each == 50:
        cat=5
    elif each == 60:
        cat=15
    elif each == 70:
        cat=10
    elif each == 75:
        cat=12
    elif each == 80:
        cat=13
    elif each == 85:
        cat=7
    elif each == 90:
        cat=6
    elif each == 120:
        cat=14
    elif each == 150:
        cat=0
    elif each == 160:
        cat=9
    elif each == 180:
        cat=1
    elif each == 190:
        cat=4
        
    SubClassNumber.append(cat)

clean_df["SubClassInt"]=SubClassNumber
#clean_df.drop("MSSubClass", axis=1, inplace=True)
clean_df.head(3)
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
#
#   SaleType SaleCondition  SalePrice  SubClassInt
# 0       WD        Normal     208500           15
# 1       WD        Normal     181500           11
# 2       WD        Normal     223500           15

# %% [markdown]
# ## Fill null values

# %%
## Many houses do not have basements.  fill basement NaN's with 'none'
clean_df['BsmtQual'].fillna('none', inplace=True)
clean_df['BsmtCond'].fillna('none', inplace=True)
clean_df['BsmtExposure'].fillna('none', inplace=True)
clean_df['BsmtFinType1'].fillna('none', inplace=True)
clean_df['BsmtFinType2'].fillna('none', inplace=True)
clean_df.head(3)
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
#
#   SaleType SaleCondition  SalePrice  SubClassInt
# 0       WD        Normal     208500           15
# 1       WD        Normal     181500           11
# 2       WD        Normal     223500           15

# %%
## fill Alley NaN's with 'none'
clean_df['Alley'].fillna('none', inplace=True)

## fil Lot Frontage with Median
median=clean_df['LotFrontage'].median()
clean_df['LotFrontage'].fillna(median, inplace=True)

# %%
## drop 1 row with NaN for Electrical
clean_df.dropna(axis=0, subset=['Electrical'], inplace=True)

# %%
## fil fireplaceQual NaN's with 'none'
clean_df['FireplaceQu'].fillna('none', inplace=True)

# %%
## take care of garage NaN's

clean_df['GarageType'].fillna('none', inplace=True)
clean_df['GarageYrBlt'].fillna(0, inplace=True)
clean_df['GarageFinish'].fillna('none', inplace=True)
clean_df['GarageQual'].fillna('none', inplace=True)
clean_df['GarageCond'].fillna('none', inplace=True)

# %%
## Pool NaN's
clean_df['PoolQC'].fillna('none', inplace=True)
## Fence
clean_df['Fence'].fillna('none', inplace=True)
## MiscFeature
clean_df['MiscFeature'].fillna('none', inplace=True)

# %%
# vnr=clean_df.loc[clean_df['MasVnrType'].isnull()]
# vnr

clean_df['MasVnrType'].fillna('none', inplace=True)
clean_df['MasVnrArea'].fillna(0, inplace=True)

# %%
### No more NaN's in dataset
clean_df.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
#                 ..
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# SubClassInt      0
# Length: 81, dtype: int64

# %% [markdown]
# ## Quality can be numerical

# %%
## Exterior Quality can be numerical
exqual=[]

for each in clean_df['ExterQual']:
    if each=='Ex':
        q=5
    elif each =='Gd':
        q=4
    elif each =='TA':
        q=3
    elif each =='Fa':
        q=2
    elif each =='Po':
        q=1
    exqual.append(q)
    
clean_df['ExtQuality']=exqual
clean_df.drop('ExterQual', axis=1, inplace=True)
clean_df.head(2)
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave  none      Reg
# 1          20       RL         80.0     9600   Pave  none      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
#
#    MasVnrArea ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        TA      PConc       Gd       TA           No
# 1         0.0        TA     CBlock       Gd       TA           Gd
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0        none
# 1             1          TA             6        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0   none  none        none        0       2    2008
# 1            0         0   none  none        none        0       5    2007
#
#   SaleType SaleCondition  SalePrice  SubClassInt  ExtQuality
# 0       WD        Normal     208500           15           4
# 1       WD        Normal     181500           11           3

# %%
## Exterior condition can be numerical
excond=[]

for each in clean_df['ExterCond']:
    if each=='Ex':
        q=5
    elif each =='Gd':
        q=4
    elif each =='TA':
        q=3
    elif each =='Fa':
        q=2
    elif each =='Po':
        q=1
    excond.append(q)
    
clean_df['ExtCondition']=excond
clean_df.drop('ExterCond', axis=1, inplace=True)
clean_df.head(2)
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave  none      Reg
# 1          20       RL         80.0     9600   Pave  none      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
#
#    MasVnrArea Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 0       196.0      PConc       Gd       TA           No          GLQ
# 1         0.0     CBlock       Gd       TA           Gd          ALQ
#
#    BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  \
# 0         706          Unf           0        150          856    GasA
# 1         978          Unf           0        284         1262    GasA
#
#   HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0        Ex          Y      SBrkr       856       854             0
# 1        Ex          Y      SBrkr      1262         0             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0        none
# 1             1          TA             6        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0   none  none        none        0       2    2008
# 1            0         0   none  none        none        0       5    2007
#
#   SaleType SaleCondition  SalePrice  SubClassInt  ExtQuality  ExtCondition
# 0       WD        Normal     208500           15           4             3
# 1       WD        Normal     181500           11           3             3

# %%
## Basement Quality can be numerical
bqual=[]

for each in clean_df['BsmtQual']:
    if each=='Ex':
        q=5
    elif each =='Gd':
        q=4
    elif each =='TA':
        q=3
    elif each =='Fa':
        q=2
    elif each =='Po':
        q=1
    elif each == 'none':
        q=0
    bqual.append(q)
    
clean_df['BsmtQuality']=bqual

# %%
## basement condition can be numerical

bcond=[]

for each in clean_df['BsmtCond']:
    if each=='Ex':
        q=5
    elif each =='Gd':
        q=4
    elif each =='TA':
        q=3
    elif each =='Fa':
        q=2
    elif each =='Po':
        q=1
    elif each == 'none':
        q=0
    bcond.append(q)

clean_df["BasementCond"]=bcond

# %%
## HeatingQC can be numerical
hq=[]

for each in clean_df['HeatingQC']:
    if each=='Ex':
        q=5
    elif each =='Gd':
        q=4
    elif each =='TA':
        q=3
    elif each =='Fa':
        q=2
    elif each =='Po':
        q=1
    hq.append(q)

clean_df['HeatQuality']=hq

## leave string version in dataframe.  will check correlations later and remove low values
##clean_df.drop('HeatingQC', axis=1, inplace=True)

# %%
## Central Air
ac=[]

for each in clean_df['CentralAir']:
    if each == 'N':
        v=0
    elif each == 'Y':
        v=1
    ac.append(v)
    
clean_df['CentralAC']=ac
clean_df.drop('CentralAir', axis=1, inplace=True)

# %%
## Kitchen Quaity
kq=[]

for each in clean_df['KitchenQual']:
    if each=='Ex':
        q=5
    elif each =='Gd':
        q=4
    elif each =='TA':
        q=3
    elif each =='Fa':
        q=2
    elif each =='Po':
        q=1
    kq.append(q)
    
clean_df['KitchQuality']=kq
##clean_df.drop('KitchenQual', axis=1, inplace=True)

# %%
## Functional
fnc=[]

for each in clean_df['Functional']:
    if each=='Typ':
        q=8
    elif each =='Min1':
        q=7
    elif each =='Min2':
        q=6
    elif each =='Mod':
        q=5
    elif each =='Maj1':
        q=4
    elif each =='Maj2':
        q=3
    elif each == 'Sev':
        q=2
    elif each == 'Sal':
        q=1
    fnc.append(q)
    
clean_df['Functionality']=fnc
##clean_df.drop('Functional', axis=1, inplace=True)
clean_df.head(2)
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave  none      Reg
# 1          20       RL         80.0     9600   Pave  none      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
#
#    MasVnrArea Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 0       196.0      PConc       Gd       TA           No          GLQ
# 1         0.0     CBlock       Gd       TA           Gd          ALQ
#
#    BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  \
# 0         706          Unf           0        150          856    GasA
# 1         978          Unf           0        284         1262    GasA
#
#   HeatingQC Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  \
# 0        Ex      SBrkr       856       854             0       1710
# 1        Ex      SBrkr      1262         0             0       1262
#
#    BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 0             1             0         2         1             3             1
# 1             0             1         2         0             3             1
#
#   KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  \
# 0          Gd             8        Typ           0        none     Attchd
# 1          TA             6        Typ           1          TA     Attchd
#
#    GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond  \
# 0       2003.0          RFn           2         548         TA         TA
# 1       1976.0          RFn           2         460         TA         TA
#
#   PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0          Y           0           61              0          0            0
# 1          Y         298            0              0          0            0
#
#    PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 0         0   none  none        none        0       2    2008       WD
# 1         0   none  none        none        0       5    2007       WD
#
#   SaleCondition  SalePrice  SubClassInt  ExtQuality  ExtCondition  \
# 0        Normal     208500           15           4             3
# 1        Normal     181500           11           3             3
#
#    BsmtQuality  BasementCond  HeatQuality  CentralAC  KitchQuality  \
# 0            4             3            5          1             4
# 1            4             3            5          1             3
#
#    Functionality
# 0              8
# 1              8

# %%
## Fireplace Quality
fpq=[]

for each in clean_df['FireplaceQu']:
    if each=='Ex':
        q=5
    elif each =='Gd':
        q=4
    elif each =='TA':
        q=3
    elif each =='Fa':
        q=2
    elif each =='Po':
        q=1
    elif each == 'none':
        q=0
    fpq.append(q)
    
clean_df['FireplaceQuality']=fpq
##clean_df.drop('FireplaceQu', axis=1, inplace=True)

# %%
## Garage Quality

gq=[]

for each in clean_df['GarageQual']:
    if each=='Ex':
        q=5
    elif each =='Gd':
        q=4
    elif each =='TA':
        q=3
    elif each =='Fa':
        q=2
    elif each =='Po':
        q=1
    elif each == 'none':
        q=0
    gq.append(q)
    
clean_df['GarageQuality']=gq

# %%
gc=[]

for each in clean_df['GarageCond']:
    if each=='Ex':
        q=5
    elif each =='Gd':
        q=4
    elif each =='TA':
        q=3
    elif each =='Fa':
        q=2
    elif each =='Po':
        q=1
    elif each == 'none':
        q=0
    gc.append(q)
    
clean_df['GarageCondition']=gc

# %%
### Add a column using Median Neighborhood value

medsaledf=data.groupby('Neighborhood').median()
medsaledf['SalePrice'].sort_values()
# Out:
# Neighborhood
# MeadowV     88000.0
# IDOTRR     103000.0
# BrDale     106000.0
# OldTown    119000.0
# Edwards    121750.0
# BrkSide    124300.0
# Sawyer     135000.0
# Blueste    137500.0
# SWISU      139500.0
# NAmes      140000.0
# NPkVill    146000.0
# Mitchel    153500.0
# SawyerW    179900.0
# Gilbert    181000.0
# NWAmes     182900.0
# Blmngtn    191000.0
# CollgCr    197200.0
# ClearCr    200250.0
# Crawfor    200624.0
# Veenker    218000.0
# Somerst    225500.0
# Timber     228475.0
# StoneBr    278000.0
# NoRidge    301500.0
# NridgHt    315000.0
# Name: SalePrice, dtype: float64

# %%
meds=[]

for each in clean_df['Neighborhood']:
    if each == 'MeadowV':
        m=88000
    elif each == 'IDOTRR':
        m=103000
    elif each == 'BrDale':
        m=106000
    elif each == 'OldTown':
        m=119000
    elif each == 'Edwards':
        m=121750
    elif each == 'BrkSide':
        m=124300
    elif each == 'Sawyer':
        m=135000
    elif each == 'Blueste':
        m=137500
    elif each == 'SWISU':
        m=139500
    elif each == 'NAmes':
        m=140000
    elif each == 'NPkVill':
        m=146000
    elif each == 'Mitchel':
        m=153500
    elif each == 'SawyerW':
        m=179900
    elif each == 'Gilbert':
        m=181000
    elif each == 'NWAmes':
        m=182900
    elif each == 'Blmngtn':
        m=191000
    elif each == 'CollgCr':
        m=197200
    elif each == 'ClearCr':
        m=200250
    elif each == 'Crawfor':
        m=200624
    elif each == 'Veenker':
        m=218000
    elif each == 'Somerst':
        m=225500
    elif each == 'Timber':
        m=228475
    elif each == 'StoneBr':
        m=278000
    elif each == 'NoRidge':
        m=301500
    elif each == 'NridgHt':
        m=315000
        
    meds.append(m)
    
clean_df['NeighborhoodMedValue']=meds
#clean_df.drop('Neighborhood', axis=1, inplace=True)

# %%
## Add a column using Zoning median Price

zmed=[]

for each in clean_df['MSZoning']:
    if each == 'C(all)':
        z=74700
    elif each == 'RM':
        z=120500
    elif each == 'RH':
        z=136500
    elif each == 'RL':
        z=174000
    elif each == 'FV':
        z=205950
    zmed.append(z)
    
clean_df['ZoningMedian']=zmed

# %%
## Add a column changing Electrical to representative of mean saleprice per category
Elec=[]

for each in clean_df['Electrical']:
    if each == 'Mix':
        E=.67
    elif each =='FuseP':
        E=.97
    elif each == 'FuseF':
        E=1.08
    elif each == 'FuseA':
        E=1.22
    elif each =='SBrkr':
        E=1.87
    Elec.append(E)
    
clean_df["ElectricalCat"]=Elec

# %%
## Paved Drive based on Median sale price
paved=[]
for each in clean_df['PavedDrive']:
    if each == 'N':
        p=1.11
    elif each == 'P':
        p=1.32
    elif each == 'Y':
        p=1.69
    paved.append(p)

clean_df['Driveway']=paved

# %%
## PoolQC based on average sale Price
pq=[]
for each in clean_df['PoolQC']:
    if each == 'none':
        p=1.8
    elif each == 'Gd':
        p=2
    elif each == 'Fa':
        p=2.2
    elif each == 'Ex':
        p=4.9
    pq.append(p)
    
clean_df['PoolQuality']=pq

# %%
## Add a column TotalSquareFeet
clean_df['TotalSF']= clean_df['1stFlrSF']+clean_df['2ndFlrSF']
## total sq ft plus basement
clean_df['TotSFInclBsmt']= clean_df['TotalSF']+clean_df['TotalBsmtSF']
## Total Full Bath
clean_df['TotFullBath']=clean_df['BsmtFullBath']+clean_df['FullBath']
## Total Half Bath
clean_df['TotHalfBath']=clean_df['BsmtHalfBath']+clean_df['HalfBath']
## Total Baths with half baths represented as 0.1
clean_df['TotalBaths']=clean_df['TotFullBath']+(clean_df['TotHalfBath']*0.1)

# %%
### Add a column using  Median TotSFInclBsmt per NeighborhoodMedValue

medSF=clean_df.groupby('NeighborhoodMedValue').median()
medSF['TotalSF'].sort_values()
# Out:
# NeighborhoodMedValue
# 88000     1092.0
# 135000    1106.0
# 103000    1111.0
# 106000    1155.0
# 140000    1196.0
# 121750    1200.0
# 153500    1204.0
# 124300    1210.5
# 146000    1322.0
# 119000    1368.0
# 137500    1392.5
# 218000    1437.0
# 197200    1500.0
# 191000    1500.0
# 225500    1564.5
# 181000    1593.0
# 179900    1603.0
# 182900    1664.0
# 139500    1691.0
# 228475    1692.0
# 200624    1717.0
# 200250    1738.0
# 278000    1742.0
# 315000    1850.0
# 301500    2418.0
# Name: TotalSF, dtype: float64

# %%
medsf=[]

for each in clean_df['NeighborhoodMedValue']:
    if each == 88000:
        m=1092
    elif each == 103000:
        m=1111
    elif each == 106000:
        m=1155
    elif each == 119000:
        m=1368
    elif each == 121750:
        m=1200
    elif each == 124300:
        m=1210
    elif each == 135000:
        m=1106
    elif each == 137500:
        m=1392
    elif each == 139500:
        m=1691
    elif each == 140000:
        m=1196
    elif each == 146000:
        m=1322
    elif each == 153500:
        m=1204
    elif each == 179900:
        m=1603
    elif each == 181000:
        m=1593
    elif each == 182900:
        m=1664
    elif each == 191000:
        m=1500
    elif each == 197200:
        m=1500
    elif each == 200250:
        m=1738
    elif each == 200624:
        m=1717
    elif each == 218000:
        m=1437
    elif each == 225500:
        m=1564
    elif each == 228475:
        m=1692
    elif each == 278000:
        m=1742
    elif each == 301500:
        m=2418
    elif each == 315000:
        m=1850
        
    medsf.append(m)
    
clean_df['MedianSFByNeighborhood']=medsf

# %%
clean_df.head(1)
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave  none      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 0       196.0      PConc       Gd       TA           No          GLQ
#
#    BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  \
# 0         706          Unf           0        150          856    GasA
#
#   HeatingQC Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  \
# 0        Ex      SBrkr       856       854             0       1710
#
#    BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 0             1             0         2         1             3             1
#
#   KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  \
# 0          Gd             8        Typ           0        none     Attchd
#
#    GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond  \
# 0       2003.0          RFn           2         548         TA         TA
#
#   PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0          Y           0           61              0          0            0
#
#    PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 0         0   none  none        none        0       2    2008       WD
#
#   SaleCondition  SalePrice  SubClassInt  ExtQuality  ExtCondition  \
# 0        Normal     208500           15           4             3
#
#    BsmtQuality  BasementCond  HeatQuality  CentralAC  KitchQuality  \
# 0            4             3            5          1             4
#
#    Functionality  FireplaceQuality  GarageQuality  GarageCondition  \
# 0              8                 0              3                3
#
#    NeighborhoodMedValue  ZoningMedian  ElectricalCat  Driveway  PoolQuality  \
# 0                197200        174000           1.87      1.69          1.8
#
#    TotalSF  TotSFInclBsmt  TotFullBath  TotHalfBath  TotalBaths  \
# 0     1710           2566            3            1         3.1
#
#    MedianSFByNeighborhood
# 0                    1500

# %%
#clean_df[['ElectricalCat', 'SalePrice']].groupby('ElectricalCat').mean().sort_values(by='SalePrice', ascending=True)
#clean_df['MiscVal'].value_counts()
#clean_df.loc[clean_df['LotFrontage']>150]

# %%
corr_matrix=clean_df.corr()
corrDF=clean_df
#corrDF=clean_df.loc[clean_df['TotalBsmtSF']<2500]
corrDF[[ 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'TotFullBath', 'TotHalfBath', 'TotalBaths', 'SalePrice']].corr()
# Out:
#               BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  TotFullBath  \
# BsmtFullBath      1.000000     -0.148044 -0.064097 -0.030238     0.660459
# BsmtHalfBath     -0.148044      1.000000 -0.054418 -0.012144    -0.145861
# FullBath         -0.064097     -0.054418  1.000000  0.135815     0.706985
# HalfBath         -0.030238     -0.012144  0.135815  1.000000     0.080760
# TotFullBath       0.660459     -0.145861  0.706985  0.080760     1.000000
# TotHalfBath      -0.091263      0.420071  0.099801  0.902323     0.010415
# TotalBaths        0.651183     -0.113667  0.711941  0.148483     0.997155
# SalePrice         0.227082     -0.016873  0.560881  0.284400     0.582941
#
#               TotHalfBath  TotalBaths  SalePrice
# BsmtFullBath    -0.091263    0.651183   0.227082
# BsmtHalfBath     0.420071   -0.113667  -0.016873
# FullBath         0.099801    0.711941   0.560881
# HalfBath         0.902323    0.148483   0.284400
# TotFullBath      0.010415    0.997155   0.582941
# TotHalfBath      1.000000    0.085756   0.250836
# TotalBaths       0.085756    1.000000   0.599733
# SalePrice        0.250836    0.599733   1.000000

# %%
### Check drop 1st and 2nd floor sf.  TotSFInclBsmt has highest corr at .78
###check ElectricalCat vs Electrical correlation
## TotalBaths has highest corr at .6

# %%
clean_df.head(1)
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave  none      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 0       196.0      PConc       Gd       TA           No          GLQ
#
#    BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  \
# 0         706          Unf           0        150          856    GasA
#
#   HeatingQC Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  \
# 0        Ex      SBrkr       856       854             0       1710
#
#    BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 0             1             0         2         1             3             1
#
#   KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  \
# 0          Gd             8        Typ           0        none     Attchd
#
#    GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond  \
# 0       2003.0          RFn           2         548         TA         TA
#
#   PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0          Y           0           61              0          0            0
#
#    PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 0         0   none  none        none        0       2    2008       WD
#
#   SaleCondition  SalePrice  SubClassInt  ExtQuality  ExtCondition  \
# 0        Normal     208500           15           4             3
#
#    BsmtQuality  BasementCond  HeatQuality  CentralAC  KitchQuality  \
# 0            4             3            5          1             4
#
#    Functionality  FireplaceQuality  GarageQuality  GarageCondition  \
# 0              8                 0              3                3
#
#    NeighborhoodMedValue  ZoningMedian  ElectricalCat  Driveway  PoolQuality  \
# 0                197200        174000           1.87      1.69          1.8
#
#    TotalSF  TotSFInclBsmt  TotFullBath  TotHalfBath  TotalBaths  \
# 0     1710           2566            3            1         3.1
#
#    MedianSFByNeighborhood
# 0                    1500

# %% [markdown]
# ## Find Outliers

# %%
#clean_df['TotSFInclBsmt'].hist(figsize=(12,5))

# %%
newdf=clean_df.copy()

# %%
newdf=newdf.loc[newdf['SalePrice']<470000]

# %%
newdf.drop([523, 1298], inplace=True)
newdf.drop('Street', axis=1, inplace=True)
newdf.drop(['BsmtFinSF2', 'BsmtUnfSF'], axis=1, inplace=True)
newdf.drop('3SsnPorch', axis=1, inplace=True)
newdf.drop('ScreenPorch', axis=1, inplace=True)
newdf.drop('1stFlrSF', axis=1, inplace=True)
newdf.drop('2ndFlrSF', axis=1, inplace=True)
newdf.drop(['BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'TotFullBath', 'TotHalfBath'], axis=1, inplace=True)

# %%
## LotArea 

median=newdf.loc[newdf['LotArea']<50000, 'LotArea'].median()
newdf.loc[newdf['LotArea']>50000, 'LotArea']=np.nan
newdf.fillna(median, inplace=True)

newdf['LotArea'].max()
# Out:
# 46589.0

# %%
## MasVnrArea  set max to 800

temp=newdf.loc[newdf['MasVnrArea']>800]
temp[['MasVnrArea', 'SalePrice']]

#median=newdf.loc[newdf['MasVnrArea']<800, 'MasVnrArea'].median()
newdf.loc[newdf['MasVnrArea']>800, 'MasVnrArea']=np.nan
newdf.fillna(800, inplace=True)

newdf.loc[[115]]
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Alley LotShape LandContour  \
# 115         160       FV         34.0   3230.0  Pave      Reg         Lvl
#
#     Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 115    AllPub    Corner       Gtl      Somerst       Norm       Norm   TwnhsE
#
#     HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# 115     2Story            6            5       1999          1999     Gable
#
#     RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea Foundation  \
# 115  CompShg     MetalSd     MetalSd    BrkFace       800.0      PConc
#
#     BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  \
# 115       Gd       TA           No          GLQ         419          Unf
#
#      TotalBsmtSF Heating HeatingQC Electrical  LowQualFinSF  GrLivArea  \
# 115          729    GasA        Gd      SBrkr             0       1458
#
#      BedroomAbvGr  KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  \
# 115             2             1          TA             5        Typ
#
#      Fireplaces FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  \
# 115           1          Fa     Detchd       1999.0          Unf           2
#
#      GarageArea GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  \
# 115         440         TA         TA          Y           0           32
#
#      EnclosedPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  \
# 115              0         0   none  none        none        0       6
#
#      YrSold SaleType SaleCondition  SalePrice  SubClassInt  ExtQuality  \
# 115    2007       WD        Normal     176000            9           3
#
#      ExtCondition  BsmtQuality  BasementCond  HeatQuality  CentralAC  \
# 115             3            4             3            4          1
#
#      KitchQuality  Functionality  FireplaceQuality  GarageQuality  \
# 115             3              8                 2              3
#
#      GarageCondition  NeighborhoodMedValue  ZoningMedian  ElectricalCat  \
# 115                3                225500        205950           1.87
#
#      Driveway  PoolQuality  TotalSF  TotSFInclBsmt  TotalBaths  \
# 115      1.69          1.8     1458           2187         2.1
#
#      MedianSFByNeighborhood
# 115                    1564

# %%
## TotalBsmtSF set max to 2500
newdf.loc[newdf['TotalBsmtSF']>2500, 'TotalBsmtSF']=np.nan
newdf.fillna(2500, inplace=True)
newdf['TotalBsmtSF'].max()
# Out:
# 2500.0

# %%
## LotFrontage set max to 150
newdf.loc[newdf['LotFrontage']>150, 'LotFrontage']=np.nan
newdf.fillna(150, inplace=True)
newdf['LotFrontage'].max()
# Out:
# 150.0

# %%
## TotalBaths max to 4.2
newdf.loc[newdf['TotalBaths']>4.2, 'TotalBaths']=np.nan
newdf.fillna(4.2, inplace=True)
newdf['TotalBaths'].max()
# Out:
# 4.2

# %%
## Set BedroomsAbvGr max to 4
newdf.loc[newdf['BedroomAbvGr']>4, 'BedroomAbvGr']=np.nan
newdf.fillna(4, inplace=True)
newdf['BedroomAbvGr'].max()
# Out:
# 4.0

# %%
## Set GarageCars max to 3
newdf.loc[newdf['GarageCars']>3, 'GarageCars']=np.nan
newdf.fillna(3, inplace=True)
newdf['GarageCars'].max()
# Out:
# 3.0

# %%
## Limit GarageArea to 1000
newdf.loc[newdf['GarageArea']>1000, 'GarageArea']=np.nan
newdf.fillna(1000, inplace=True)
newdf['GarageArea'].max()
# Out:
# 1000.0

# %%
## Limit WoddDeckSF to 500
newdf.loc[newdf['WoodDeckSF']>500, 'WoodDeckSF']=np.nan
newdf.fillna(500, inplace=True)
newdf['WoodDeckSF'].max()
# Out:
# 500.0

# %%
## Limit OpenPorchSF to 300
newdf.loc[newdf['OpenPorchSF']>300, 'OpenPorchSF']=np.nan
newdf.fillna(300, inplace=True)
newdf['OpenPorchSF'].max()
# Out:
# 300.0

# %%
## Limit EnclosedPorch to 75
newdf.loc[newdf['EnclosedPorch']>75, 'EnclosedPorch']=np.nan
newdf.fillna(75, inplace=True)
newdf['EnclosedPorch'].max()
# Out:
# 75.0

# %%
## Set max MiscVal to 100
newdf.loc[newdf['MiscVal']>100, 'MiscVal']=np.nan
newdf.fillna(100, inplace=True)
newdf['MiscVal'].max()
# Out:
# 100.0

# %%
newdf.head(1)
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Alley LotShape LandContour  \
# 0          60       RL         65.0   8450.0  none      Reg         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
#
#   HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# 0     2Story            7            5       2003          2003     Gable
#
#   RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea Foundation BsmtQual  \
# 0  CompShg     VinylSd     VinylSd    BrkFace       196.0      PConc       Gd
#
#   BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  TotalBsmtSF  \
# 0       TA           No          GLQ         706          Unf        856.0
#
#   Heating HeatingQC Electrical  LowQualFinSF  GrLivArea  BedroomAbvGr  \
# 0    GasA        Ex      SBrkr             0       1710           3.0
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0        none
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn         2.0       548.0         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  PoolArea  \
# 0         TA          Y         0.0         61.0            0.0         0
#
#   PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType SaleCondition  \
# 0   none  none        none      0.0       2    2008       WD        Normal
#
#    SalePrice  SubClassInt  ExtQuality  ExtCondition  BsmtQuality  \
# 0     208500           15           4             3            4
#
#    BasementCond  HeatQuality  CentralAC  KitchQuality  Functionality  \
# 0             3            5          1             4              8
#
#    FireplaceQuality  GarageQuality  GarageCondition  NeighborhoodMedValue  \
# 0                 0              3                3                197200
#
#    ZoningMedian  ElectricalCat  Driveway  PoolQuality  TotalSF  TotSFInclBsmt  \
# 0        174000           1.87      1.69          1.8     1710           2566
#
#    TotalBaths  MedianSFByNeighborhood
# 0         3.1                    1500

# %%
#plt.scatter(newdf['SalePrice'], newdf['GarageArea'])

# %%
#newdf.drop([661,848], inplace=True)
      ## TotSFInclBsmt is better correlated than any other sq ft
#newdf.drop(['1stFlrSF', '2ndFlrSF'], axis=1, inplace=True)
#newdf.drop('LowQualFinSF', axis=1, inplace=True)

# %%
# corr_matrix=newdf.corr()
# newcorrDF=newdf
# #newcorrDF=newdf.loc[clean_df['TotalBsmtSF']<2500]
# newcorrDF[['TotSFInclBsmt', 'SalePrice']].corr()

# %% [markdown]
# ## Import Libraries

# %%
## Split data into train and test sets

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Use All values

# %%
binarydf=pd.get_dummies(newdf)

AX=binarydf.drop('SalePrice', axis=1)
Ay=binarydf['SalePrice']

stdscaler=StandardScaler()
AX_stdScaled=stdscaler.fit_transform(AX)

AX_train, AX_test, Ay_train, Ay_test=train_test_split(AX_stdScaled, Ay, train_size=.8, random_state=42)

# %% [markdown]
# ## Adjust R2 for all values

# %%
corr_matrixA=binarydf.corr()
corr_listA=corr_matrixA['SalePrice']
corr_dfA=pd.DataFrame(corr_listA)
corr_dfA.reset_index()

## Turn into a list to loop through
drop_listA=corr_dfA.loc[(corr_dfA['SalePrice']<0.3) & (corr_dfA['SalePrice']> -0.3)]
        
drop_listA.reset_index(inplace=True)

colsA=drop_listA['index'].tolist()

AllReduced=binarydf.copy()

for each in colsA:
    AllReduced.drop(each, axis=1, inplace=True)

# %%
ARX=AllReduced.drop('SalePrice', axis=1)
ARy=AllReduced['SalePrice']

stdscaler=StandardScaler()
ARX_stdScaled=stdscaler.fit_transform(ARX)

ARX_train, ARX_test, ARy_train, ARy_test=train_test_split(ARX_stdScaled, ARy, train_size=.8, random_state=42)

# %% [markdown]
# ##  Integer Only
# ### Create a DF with no string values for experimental purposes

# %%
integerOnlyDF=newdf.select_dtypes(include='number')
integerOnlyDF.head(2)
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0   8450.0            7            5       2003
# 1          20         80.0   9600.0            6            8       1976
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  TotalBsmtSF  GrLivArea  BedroomAbvGr  \
# 0          2003       196.0         706        856.0       1710           3.0
# 1          1976         0.0         978       1262.0       1262           3.0
#
#    KitchenAbvGr  TotRmsAbvGrd  Fireplaces  GarageYrBlt  GarageCars  \
# 0             1             8           0       2003.0         2.0
# 1             1             6           1       1976.0         2.0
#
#    GarageArea  WoodDeckSF  OpenPorchSF  EnclosedPorch  PoolArea  MiscVal  \
# 0       548.0         0.0         61.0            0.0         0      0.0
# 1       460.0       298.0          0.0            0.0         0      0.0
#
#    MoSold  YrSold  SalePrice  SubClassInt  ExtQuality  ExtCondition  \
# 0       2    2008     208500           15           4             3
# 1       5    2007     181500           11           3             3
#
#    BsmtQuality  BasementCond  HeatQuality  CentralAC  KitchQuality  \
# 0            4             3            5          1             4
# 1            4             3            5          1             3
#
#    Functionality  FireplaceQuality  GarageQuality  GarageCondition  \
# 0              8                 0              3                3
# 1              8                 3              3                3
#
#    NeighborhoodMedValue  ZoningMedian  ElectricalCat  Driveway  PoolQuality  \
# 0                197200        174000           1.87      1.69          1.8
# 1                218000        174000           1.87      1.69          1.8
#
#    TotalSF  TotSFInclBsmt  TotalBaths  MedianSFByNeighborhood
# 0     1710           2566         3.1                    1500
# 1     1262           2524         2.1                    1437

# %%
## Standard Scaler and Train_Test_Split

XIO= integerOnlyDF.drop('SalePrice', axis=1)
yIO= integerOnlyDF['SalePrice']

stdscaler=StandardScaler()
XIO_stdScaled=stdscaler.fit_transform(XIO)

XIO_train, XIO_test, yIO_train, yIO_test=train_test_split(XIO_stdScaled, yIO, train_size=.8, random_state=42)

# %% [markdown]
# #### Correlation Matrix

# %%
corr_matrix3=integerOnlyDF.corr()
#corr_matrix3['SalePrice'].sort_values(ascending=False)

# %%
corr_list3=corr_matrix3['SalePrice'].sort_values(ascending=False)
corr_df3=pd.DataFrame(corr_list3)
corr_df3.reset_index().head(1)
# Out:
#        index  SalePrice
# 0  SalePrice        1.0

# %% [markdown]
# ## Adjust X values based on R2

# %%
## Turn into a list to loop through  0.08
drop_list3=corr_df3.loc[(corr_df3['SalePrice']<0.01) & (corr_df3['SalePrice']> -0.01)]
        
drop_list3.reset_index(inplace=True)
drop_list3['index']

cols3=drop_list3['index'].tolist()

intOnlyReduced=integerOnlyDF.copy()

for each in cols3:
    intOnlyReduced.drop(each, axis=1, inplace=True)
    
intOnlyReduced.head(2)
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0   8450.0            7            5       2003
# 1          20         80.0   9600.0            6            8       1976
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  TotalBsmtSF  GrLivArea  BedroomAbvGr  \
# 0          2003       196.0         706        856.0       1710           3.0
# 1          1976         0.0         978       1262.0       1262           3.0
#
#    KitchenAbvGr  TotRmsAbvGrd  Fireplaces  GarageYrBlt  GarageCars  \
# 0             1             8           0       2003.0         2.0
# 1             1             6           1       1976.0         2.0
#
#    GarageArea  WoodDeckSF  OpenPorchSF  EnclosedPorch  PoolArea  MiscVal  \
# 0       548.0         0.0         61.0            0.0         0      0.0
# 1       460.0       298.0          0.0            0.0         0      0.0
#
#    MoSold  YrSold  SalePrice  SubClassInt  ExtQuality  ExtCondition  \
# 0       2    2008     208500           15           4             3
# 1       5    2007     181500           11           3             3
#
#    BsmtQuality  BasementCond  HeatQuality  CentralAC  KitchQuality  \
# 0            4             3            5          1             4
# 1            4             3            5          1             3
#
#    Functionality  FireplaceQuality  GarageQuality  GarageCondition  \
# 0              8                 0              3                3
# 1              8                 3              3                3
#
#    NeighborhoodMedValue  ZoningMedian  ElectricalCat  Driveway  PoolQuality  \
# 0                197200        174000           1.87      1.69          1.8
# 1                218000        174000           1.87      1.69          1.8
#
#    TotalSF  TotSFInclBsmt  TotalBaths  MedianSFByNeighborhood
# 0     1710           2566         3.1                    1500
# 1     1262           2524         2.1                    1437

# %%
## Standard Scaler & Train_test_split

XR= intOnlyReduced.drop('SalePrice', axis=1)
yR= intOnlyReduced['SalePrice']

stdscaler=StandardScaler()
XR_stdScaled=stdscaler.fit_transform(XR)

XR_train, XR_test, yR_train, yR_test=train_test_split(XR_stdScaled, yR, train_size=.75, random_state=42)

# %% [markdown]
# ## Random Forest

# %%
forest2=RandomForestRegressor()

forest2.fit(XR_train, yR_train)
forest2.score(XR_train, yR_train)
# Out:
# 0.9853687984841534

# %%
forest2.score(XR_test, yR_test)
# Out:
# 0.8806137121431172

# %%
forest2_predictions=forest2.predict(XR_test)

forest2_mse= mean_squared_error(yR_test, forest2_predictions)
forest2_rmse=np.sqrt(forest2_mse)
forest2_rmse

# XR 0.01=21,571
# AR 0.3= 22,010
# IO = 21,503
# AX = 21,457
# Out:
# 21571.98125586837

# %% [markdown]
# ## Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbrt=GradientBoostingRegressor(max_depth=50, n_estimators=6000, max_features='sqrt', learning_rate=0.001)
gbrt.fit(XR_train, yR_train)
gbrt.score(XR_train, yR_train)
# Out:
# 0.9999938925669939

# %%
gbrt.score(XR_test, yR_test)
# Out:
# 0.8907832748623319

# %%
gbrt_predictions=gbrt.predict(XR_test)

gbrt_mse= mean_squared_error(yR_test, gbrt_predictions)
gbrt_rmse=np.sqrt(gbrt_mse)
gbrt_rmse

# XR 0.01=20,632
# Out:
# 20632.76277770519

# %% [markdown]
# ## Extra Trees

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
ET=ExtraTreesRegressor()
ET.fit(AX_train, Ay_train)
ET.score(AX_train, Ay_train)
# Out:
# 1.0

# %%
ET.score(AX_test, Ay_test)
# Out:
# 0.8898453560075433

# %%
ET_predictions=ET.predict(AX_test)

ET_mse= mean_squared_error(Ay_test, ET_predictions)
ET_rmse=np.sqrt(ET_mse)
ET_rmse

# XR 0.3=21,806
# XR 0.01=20,740
# AX = 20721
# Out:
# 20721.167221900178

# %% [markdown]
# ## Elastic Net

# %%
from sklearn.linear_model import ElasticNet

# poly_features=PolynomialFeatures(degree=2, include_bias=False)
# X_poly=poly_features.fit_transform(XR_train)

Enet=ElasticNet(alpha=0.001, l1_ratio=0.001, max_iter=100000, tol=1e-4)
Enet.fit(XR_train, yR_train)
Enet.score(XR_train, yR_train)
# Out:
# 0.904990393160852

# %%
#X_polyval=poly_features.fit_transform(XR_val)

Enet.score(XR_test, yR_test)
# Out:
# 0.8637040540122151

# %%
EN_predictions=Enet.predict(XR_test)

EN_mse= mean_squared_error(yR_test, EN_predictions)
EN_rmse=np.sqrt(EN_mse)
EN_rmse

## 0.5=23,422
# Out:
# 23049.116290387516

# %% [markdown]
# ###  Elastic Randomized search

# %%
Elastic=ElasticNet()

grid= {
    'max_iter': [500000, 700000, 1000000],
    'alpha': [0.001, 0.01, 0.1, 1, 0.5],
    'l1_ratio': [0.001, 0.01, 0.1, 1, 2, 10],
    'normalize': [False],
    'tol': [0.0001, 0.00001, 0.000001]
}

Elastic_random=RandomizedSearchCV(Elastic, grid, scoring='r2', cv=5, random_state=42)

Elastic_random.fit(X_poly, yR_train)

# %%
Elastic_random.best_params_

# %%
Elastic_random.score(X_poly, yR_train)

# %%
Elastic_random.score(X_polyval, yR_val)

# %%
E_predictions=Elastic_random.predict(X_polyval)

E_mse= mean_squared_error(yR_val, E_predictions)
E_rmse=np.sqrt(E_mse)
E_rmse

## 0.05=22,782

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
KNN=KNeighborsRegressor(n_neighbors=7)
KNN.fit(XR_train, yR_train)
KNN.score(XR_train, yR_train)
# Out:
# 0.9000997744778283

# %%
KNN.score(XR_test, yR_test)
# Out:
# 0.8461513237758638

# %%
K_predictions=KNN.predict(XR_test)

K_mse= mean_squared_error(yR_test, K_predictions)
K_rmse=np.sqrt(K_mse)
K_rmse

# XR 0.01= 24,292
# AX 33,819
# Out:
# 24488.359473641187

# %% [markdown]
# ## Cross Validate

# %%
from sklearn.model_selection import cross_val_score

# %%
scores=cross_val_score(forest3, XR_train, yR_train, scoring="neg_mean_squared_error", cv=5)
forest_rmse_scores=np.sqrt(-scores)
forest_rmse_scores.mean()

# %% [markdown]
# ## Grid Search Parameters

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV

# %%
forest_model3=RandomForestRegressor()

param_grid= [
        {'bootstrap': [False], 'n_estimators': [200, 300, 400, 800], 'max_features': ['sqrt'], 'max_depth': [50, 70, 150]},
]

grid_search=GridSearchCV(forest_model3, param_grid, cv=5, scoring='neg_mean_squared_error', return_train_score=True)

grid_search.fit(XR_train, yR_train)
grid_search.best_params_

# %%
cvres=grid_search.cv_results_
for mean_score, params in zip(cvres['mean_test_score'], cvres['params']):
    print(np.sqrt(-mean_score), params)

# %%
forest_model3.fit(XR_train, yR_train)
forest_model3.score(XR_train, yR_train)

# %%
forest_model3.score(XR_val, yR_val)

# %%
f3_predictions=forest_model3.predict(XR_val)

f3_mse= mean_squared_error(yR_val, f3_predictions)
f3_rmse=np.sqrt(f3_mse)
f3_rmse

# %% [markdown]
# ## RandomizedSearchCV

# %%
rf=RandomForestRegressor()

grid= {
    'n_estimators': [85, 100, 150],
    'max_features': ['auto', 'sqrt'],
    'max_depth': [10, 25, 50, 100],
    'bootstrap': [True, False]
}

rf_random=RandomizedSearchCV(rf, grid, n_iter=64, cv=5, random_state=42)

rf_random.fit(XR_train, yR_train)

# %%
rf_random.best_params_

# %%
rf_random.score(XR_train, yR_train)

# %%
rf_random.score(XR_val, yR_val)

# %%
rf_predictions=rf_random.predict(XR_val)

rf_mse= mean_squared_error(yR_val, rf_predictions)
rf_rmse=np.sqrt(rf_mse)
rf_rmse

## 0.1=21,345
